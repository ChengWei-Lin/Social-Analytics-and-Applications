# %%
import pandas as pd

# %%
# path = "hwz data/9 CLEANED.xlsx"
# new_path = "hwz data/new 9 CLEANED.xlsx"

path = "fuck.xlsx"
# new_path = "hwz data/new 14 CLEANED.xlsx"

# %%
df = pd.read_excel(path)
df.head()
# Out:
#         username               tborder  \
# 0        TayYH89  01-01-2019, 10:28 PM
# 1        arcfire  02-01-2019, 12:10 AM
# 2         cokiee  02-01-2019, 12:28 AM
# 3  darthsid11111  02-01-2019, 07:04 AM
# 4     theblueark  02-01-2019, 07:59 AM
#
#                                         post_message  tborder1  Posts  \
# 0  First image was taken while in shop (others th...      6827    283
# 1  Jacket looks fine as it is for otr, especially...      6828  2,683
# 2  Looks like a good fit for the jacket - congrat...      6829  1,236
# 3  Congrats! It looks good for what you paid for ...      6830    NaN
# 4  Great fit on the jacket for that price. Pants ...      6831    NaN
#
#   Username Master Post                                              quote  \
# 0                  NaN                                                NaN
# 1       TayYH89 wrote:  First image was taken while in shop (others th...
# 2                  NaN                                                NaN
# ...

# %%
sb = df[df['topic']==4]

# %%
sb.shape
# Out:
# (87, 21)

# %%
sb.head()
# Out:
#          username               tborder  \
# 21  learningdandy  15-01-2019, 06:33 PM
# 24     lemniscate  16-01-2019, 09:59 PM
# 30  BabaSingapore  17-01-2019, 01:40 PM
# 31     theblueark  17-01-2019, 02:59 PM
# 34       boomeray  18-01-2019, 12:07 PM
#
#                                          post_message  tborder1 Posts  \
# 21  Anyone here tried crispairs suitings from HnS?...      6848   137
# 24  SB quoted around 3k for H&S Crispaire and Minn...      6851    83
# 30  Hello all, anyone tried these MTM tailors befo...      6857   NaN
# 31  I’ve only tried Edit Suits, which has been aro...      6858   NaN
# 34  Inpersonam and kayjendylan are within the pric...      6861    54
#
#     Username Master Post                                              quote  \
# 21                   NaN                                                NaN
# 24  learningdandy wrote:  Anyone here tried crispairs suitings from HnS?...
# ...

# %%
df.to_excel(new_path, index=False)

# %%
# Import the wordcloud library
from wordcloud import WordCloud

useless_list = ['will', 'tailor', 'using', 'one', 'Sent', 
                'Samsung', 'even', 'really', 'say', 'know',
                'make', 'write', 'back', 'go', 'good', 'think', 'look', 'sb',
                'seamless', 'bespoke', 'bespeak']

# Join the different processed titles together.
long_string = ' '.join(list(sb['clean_post_message'].values))

long_string_list = long_string.split()
long_string_list = [w for w in long_string_list if w not in useless_list]
long_string = ' '.join(long_string_list)

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=5, contour_color='steelblue', width=800, height=400)

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x2B957918198>

# %%
# Import the wordcloud library
from wordcloud import WordCloud

useless_list = ['will', 'tailor', 'using', 'one', 'Sent', 'take', 'see', 'try', 'much', 'thank', 'help', 'work', 'full',
                'Samsung', 'even', 'really', 'say', 'know', 'start', 'seem', 'anyone', 'use', 'fit',
                'people', 'still', 'though', 'find', 'first', 'thanks', 'sure', 'quite', 'two',
                'make', 'write', 'back', 'go', 'good', 'think', 'look', 'sb', 'need', 'wear', 'many',
                'seamless', 'bespoke', 'bespeak', 'shirt', 'suit', 'pant', 'trouser', 'jacket', 'fabric']

# Join the different processed titles together.
long_string = ' '.join(list(sb['clean_post_message'].values))

long_string_list = long_string.split()
long_string_list = [w for w in long_string_list if w not in useless_list]
long_string = ' '.join(long_string_list)

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=5, contour_color='steelblue', width=800, height=400)

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x2B957071C50>
